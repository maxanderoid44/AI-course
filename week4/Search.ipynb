# %% [markdown]
# # Breadth-First Search (BFS)
# `Breadth-First Search (BFS)` is an algorithm used for traversing graphs or trees. **Traversing means visiting each node of the graph.**  BFS in python can be implemented by using data structures like a dictionary and lists. (BFS) is a fundamental graph traversal algorithm . It involves visiting all the connected nodes of a graph in a `level-by-level` manner.
#
# `The steps of the algorithm work as follow:`
# 1. Start by putting any one of the graph’s vertices at the back of the queue.
# 2. Now take the front item of the queue and add it to the visited list.
# 3. Create a list of that vertex's adjacent nodes. Add those which are not within the visited list to the rear of the queue.
# 4. Keep continuing steps two and three till the queue is empty.

# %% [markdown]
# ### Let us understand the working of the algorithm with the help of the following example.

# %% [markdown]
# 1. Start by putting any one of the graph’s vertices at the back of the queue.
# 2. Now take the front item of the queue and add it to the visited list.
# 3. Create a list of that vertex's adjacent nodes. Add those which are not within the visited list to the rear of the queue.
# 4. Keep continuing steps two and three till the queue is empty.

# %% [markdown]
# ### BFS Pseudocode
#
#
# 1. create a queue Q
#
# 2. mark v as visited and put v into Q
#
# 3. while Q is non-empty
#
#     3.1 remove the head u of Q
#
#     3.2 mark and enqueue all (unvisited) neighbors of u
#
#     mark and enqueue all (unvisited) neighbors of u

# %% [markdown]
# ### BFS Implementation in Python (Source Code)
#
# ![image.png](attachment:image.png)

# %%
# Graph with Adjacency List
graph = {
  '5' : ['3','7'],
  '7' : ['8'],
  '3' : ['2', '4'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}

# %%
visited = [] # List for visited nodes.
queue = [] #Initialize a queue or Stack

# %%
#function for BFS 
def bfs(visited, graph, root):
    # Add root to visited and to queue
    
     # Creating loop to visit each node
     ## and add each node to the queue

    while queue:
        pass
        #dequeue a vertex from queue

        # Get all adjacent vertices of the dequeued vertex

        # If a adjacent has not been visited, then mark it
        # visited and enqueue it

# %%
# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, '5')    # function calling
# Out:
# Following is the Breadth-First Search

# %%
graph = {
  '5' : ['3','7'],
  '7' : ['8'],
  '3' : ['2', '4'],
  '2' : [],
  '4' : ['8'],
  '8' : []
}

visited = [] # List for visited nodes.
queue = []     #Initialize a queue

def bfs(visited, graph, node ,goal): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0) 
    print (m, end = " ") 
    if m == goal:
      return
    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, '5','4')    # function calling
# Out:
# Following is the Breadth-First Search
# 5 3 7 2 4

# %% [markdown]
# # Depth First Search (DFS)
# `The Depth-First Search is a recursive algorithm that uses the concept of backtracking.` It involves thorough searches of all the nodes by going ahead if potential, else by backtracking. Here, the word backtrack means once you are moving forward and there are not any more nodes along the present path,

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Using a Python dictionary to act as an adjacency list
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : ['3'],
  '4' : ['8'],
  '8' : ['4','7']
}

visited = set() # Set to keep track of visited nodes of graph.
t = False
def dfs(visited, graph, start,goal):  #function for dfs 
    if start not in visited:
        global t
        if t == False:
            print (start, end = " ")
            visited.add(start)
            if start == goal:
                t = True
            for neighbour in graph[start]:
                dfs(visited, graph, neighbour,goal)

# Driver Code
print("Following is the Depth-First Search")
dfs(visited, graph, '5','8')
# Out:
# Following is the Depth-First Search
# 5 3 2 4 8

# %%
# Using a Python dictionary to act as an adjacency list
graph = {
  '5' : ['3','7'],
  '3' : ['2', '4'],
  '7' : ['8'],
  '2' : ['3'],
  '4' : ['8'],
  '8' : ['4','7']
}

visited = set() # Set to keep track of visited nodes of graph.

def dfs(visited, graph, node, goal):  #function for dfs 
    if node not in visited:
        if node == goal:
            return
        print (node, end = " ")
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour, goal)

# Driver Code
print("Following is the Depth-First Search")
dfs(visited, graph, '5', '8')
